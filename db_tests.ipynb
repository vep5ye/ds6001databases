# %% [markdown]
# ## Testing whether the database systems initialized properly
# ### 1. Importing needed Python packages

# %%
import mysql.connector
import psycopg
import pymongo
from sqlalchemy import create_engine
import dotenv
import os
dotenv.load_dotenv()
# Out:
# True

# %% [markdown]
# ### 2. Loading enviromental variables

# %%
POSTGRES_PASSWORD = os.getenv('POSTGRES_PASSWORD')
MONGO_INITDB_ROOT_USERNAME = os.getenv('MONGO_INITDB_ROOT_USERNAME')
MONGO_INITDB_ROOT_PASSWORD = os.getenv('MONGO_INITDB_ROOT_PASSWORD')
MYSQL_ROOT_PASSWORD = os.getenv('MYSQL_ROOT_PASSWORD')

# %%
MYSQL_ROOT_PASSWORD
# Out:
# 'endgame'

# %% [markdown]
# ### 3. MySQL

# %%
dbserver = mysql.connector.connect(
    user='root', 
    password=MYSQL_ROOT_PASSWORD, 
    #password='redlobstercheddarbiscuits',
    host='127.0.0.1',
    port='3306',
    auth_plugin='mysql_native_password'
)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 dbserver = mysql.connector.connect(
#       2     user='root',
#       3     password=MYSQL_ROOT_PASSWORD,
#       4     #password='redlobstercheddarbiscuits',
#       5     host='127.0.0.1',
#       6     port='3306',
#       7     auth_plugin='mysql_native_password'
#       8 )
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/mysql/connector/pooling.py:323, in connect(*args, **kwargs)
#     321 if CMySQLConnection and not use_pure:
#     322     return CMySQLConnection(*args, **kwargs)
# --> 323 return MySQLConnection(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/mysql/connector/connection.py:173, in MySQLConnection.__init__(self, **kwargs)
#     171 if kwargs:
#     172     try:
# --> 173         self.connect(**kwargs)
#     174     except Exception:
#     175         # Tidy-up underlying socket on failure
#     176         self.close()
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/mysql/connector/abstracts.py:1363, in MySQLConnectionAbstract.connect(self, **kwargs)
#    1360     self.config(**kwargs)
#    1362 self.disconnect()
# -> 1363 self._open_connection()
#    1365 charset, collation = (
#    1366     kwargs.pop("charset", None),
#    1367     kwargs.pop("collation", None),
#    1368 )
#    1369 if charset or collation:
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/mysql/connector/connection.py:359, in MySQLConnection._open_connection(self)
#     356 self._do_handshake()
#     358 # start authentication negotiation
# --> 359 self._do_auth(
#     360     self._user,
#     361     self._password,
#     362     self._database,
#     363     self._client_flags,
#     364     self._charset_id,
#     365     self._ssl,
#     366     self._conn_attrs,
#     367 )
#     368 self.set_converter_class(self._converter_class)
#     370 if self._client_flags & ClientFlag.COMPRESS:
#     371     # update the network layer accordingly
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/mysql/connector/connection.py:292, in MySQLConnection._do_auth(self, username, password, database, client_flags, charset, ssl_options, conn_attrs)
#     283     self._authenticator.setup_ssl(
#     284         self._socket,
#     285         self.server_host,
#    (...)
#     288         client_flags=client_flags,
#     289     )
#     290     self._ssl_active = True
# --> 292 ok_pkt = self._authenticator.authenticate(
#     293     sock=self._socket,
#     294     handshake=self._handshake,
#     295     username=username,
#     296     password1=password,
#     297     password2=self._password2,
#     298     password3=self._password3,
#     299     database=database,
#     300     charset=charset,
#     301     client_flags=client_flags,
#     302     auth_plugin=self._auth_plugin,
#     303     auth_plugin_class=self._auth_plugin_class,
#     304     conn_attrs=conn_attrs,
#     305     krb_service_principal=self._krb_service_principal,
#     306     oci_config_file=self._oci_config_file,
#     307     oci_config_profile=self._oci_config_profile,
#     308     webauthn_callback=self._webauthn_callback,
#     309     fido_callback=self._fido_callback,
#     310 )
#     311 self._handle_ok(ok_pkt)
#     313 if not (client_flags & ClientFlag.CONNECT_WITH_DB) and database:
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/mysql/connector/authentication.py:371, in MySQLAuthenticator.authenticate(self, sock, handshake, username, password1, password2, password3, database, charset, client_flags, max_allowed_packet, auth_plugin, auth_plugin_class, conn_attrs, is_change_user_request, **plugin_config)
#     368 # server replies back
#     369 pkt = bytes(sock.recv())
# --> 371 ok_pkt = self._handle_server_response(sock, pkt)
#     372 if ok_pkt is None:
#     373     raise InterfaceError("Got a NULL ok_pkt") from None
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/mysql/connector/authentication.py:285, in MySQLAuthenticator._handle_server_response(self, sock, pkt)
#     282     return self._mfa_n_factor(sock, pkt)
#     284 if pkt[4] == ERR_STATUS:
# --> 285     raise get_exception(pkt)
#     287 return None
#
# ProgrammingError: 1045 (28000): Access denied for user 'root'@'192.168.65.1' (using password: YES)

# %% [markdown]
# ### 4. PostgreSQL

# %%
dbserver = psycopg.connect(
    user='postgres', 
    password=POSTGRES_PASSWORD, 
    host="localhost"
)
dbserver.autocommit = True
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 dbserver = psycopg.connect(
#       2     user='postgres',
#       3     password=POSTGRES_PASSWORD,
#       4     host="localhost"
#       5 )
#       6 dbserver.autocommit = True
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/psycopg/connection.py:749, in Connection.connect(cls, conninfo, autocommit, prepare_threshold, row_factory, cursor_factory, context, **kwargs)
#     747 if not rv:
#     748     assert last_ex
# --> 749     raise last_ex.with_traceback(None)
#     751 rv._autocommit = bool(autocommit)
#     752 if row_factory:
#
# OperationalError: connection failed: FATAL:  password authentication failed for user "postgres"

# %% [markdown]
# ### 5. Mongo DB

# %%
myclient = pymongo.MongoClient(f"mongodb://{MONGO_INITDB_ROOT_USERNAME}:{MONGO_INITDB_ROOT_PASSWORD}@localhost/")

# %%
myclient.list_databases()
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 myclient.list_databases()
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/pymongo/mongo_client.py:1925, in MongoClient.list_databases(self, session, comment, **kwargs)
#    1923     cmd["comment"] = comment
#    1924 admin = self._database_default_options("admin")
# -> 1925 res = admin._retryable_read_command(cmd, session=session)
#    1926 # listDatabases doesn't return a cursor (yet). Fake one.
#    1927 cursor = {
#    1928     "id": 0,
#    1929     "firstBatch": res["databases"],
#    1930     "ns": "admin.$cmd",
#    1931 }
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/pymongo/database.py:1026, in Database._retryable_read_command(self, command, session)
#    1013 def _cmd(
#    1014     session: Optional[ClientSession],
#    1015     _server: Server,
#    1016     conn: Connection,
#    1017     read_preference: _ServerMode,
#    1018 ) -> dict[str, Any]:
#    1019     return self._command(
#    1020         conn,
#    1021         command,
#    1022         read_preference=read_preference,
#    1023         session=session,
#    1024     )
# -> 1026 return self.__client._retryable_read(_cmd, read_preference, session)
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/pymongo/mongo_client.py:1492, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1487 # Ensure that the client supports retrying on reads and there is no session in
#    1488 # transaction, otherwise, we will not support retry behavior for this call.
#    1489 retryable = bool(
#    1490     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1491 )
# -> 1492 return self._retry_internal(
#    1493     func,
#    1494     session,
#    1495     None,
#    1496     is_read=True,
#    1497     address=address,
#    1498     read_pref=read_pref,
#    1499     retryable=retryable,
#    1500 )
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/pymongo/mongo_client.py:1462, in MongoClient._retry_internal(self, func, session, bulk, is_read, address, read_pref, retryable)
#    1428 @_csot.apply
#    1429 def _retry_internal(
#    1430     self,
#    (...)
#    1437     retryable: bool = False,
#    1438 ) -> T:
#    1439     """Internal retryable helper for all client transactions.
#    1440
#    1441     :Parameters:
#    (...)
#    1451       Output of the calling func()
#    1452     """
#    1453     return _ClientConnectionRetryable(
#    1454         mongo_client=self,
#    1455         func=func,
#    1456         bulk=bulk,
#    1457         is_read=is_read,
#    1458         session=session,
#    1459         read_pref=read_pref,
#    1460         address=address,
#    1461         retryable=retryable,
# -> 1462     ).run()
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/pymongo/mongo_client.py:2315, in _ClientConnectionRetryable.run(self)
#    2313 self._check_last_error(check_csot=True)
#    2314 try:
# -> 2315     return self._read() if self._is_read else self._write()
#    2316 except ServerSelectionTimeoutError:
#    2317     # The application may think the write was never attempted
#    2318     # if we raise ServerSelectionTimeoutError on the retry
#    2319     # attempt. Raise the original exception instead.
#    2320     self._check_last_error()
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/pymongo/mongo_client.py:2439, in _ClientConnectionRetryable._read(self)
#    2437 self._server = self._get_server()
#    2438 assert self._read_pref is not None, "Read Preference required on read calls"
# -> 2439 with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2440     conn,
#    2441     read_pref,
#    2442 ):
#    2443     if self._retrying and not self._retryable:
#    2444         self._check_last_error()
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/pymongo/mongo_client.py:1330, in MongoClient._conn_from_server(self, read_preference, server, session)
#    1327 topology = self._get_topology()
#    1328 single = topology.description.topology_type == TOPOLOGY_TYPE.Single
# -> 1330 with self._checkout(server, session) as conn:
#    1331     if single:
#    1332         if conn.is_repl and not (session and session.in_transaction):
#    1333             # Use primary preferred to ensure any repl set member
#    1334             # can handle the request.
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/pymongo/mongo_client.py:1252, in MongoClient._checkout(self, server, session)
#    1250     yield session._pinned_connection
#    1251     return
# -> 1252 with server.checkout(handler=err_handler) as conn:
#    1253     # Pin this session to the selected server or connection.
#    1254     if (
#    1255         in_txn
#    1256         and session
#    (...)
#    1261         )
#    1262     ):
#    1263         session._pin(server, conn)
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/pymongo/pool.py:1637, in Pool.checkout(self, handler)
#    1634     assert listeners is not None
#    1635     listeners.publish_connection_check_out_started(self.address)
# -> 1637 conn = self._get_conn(handler=handler)
#    1639 if self.enabled_for_cmap:
#    1640     assert listeners is not None
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/pymongo/pool.py:1756, in Pool._get_conn(self, handler)
#    1754 else:  # We need to create a new connection
#    1755     try:
# -> 1756         conn = self.connect(handler=handler)
#    1757     finally:
#    1758         with self._max_connecting_cond:
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/pymongo/pool.py:1607, in Pool.connect(self, handler)
#    1604     if handler:
#    1605         handler.contribute_socket(conn, completed_handshake=False)
# -> 1607     conn.authenticate()
#    1608 except BaseException:
#    1609     conn.close_conn(ConnectionClosedReason.ERROR)
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/pymongo/pool.py:1078, in Connection.authenticate(self, reauthenticate)
#    1076 creds = self.opts._credentials
#    1077 if creds:
# -> 1078     auth.authenticate(creds, self, reauthenticate=reauthenticate)
#    1079 self.ready = True
#    1080 if self.enabled_for_cmap:
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/pymongo/auth.py:625, in authenticate(credentials, conn, reauthenticate)
#     623     _authenticate_oidc(credentials, conn, reauthenticate)
#     624 else:
# --> 625     auth_func(credentials, conn)
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/pymongo/auth.py:528, in _authenticate_default(credentials, conn)
#     526     mechs = conn.command(source, cmd, publish_events=False).get("saslSupportedMechs", [])
#     527 if "SCRAM-SHA-256" in mechs:
# --> 528     return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     529 else:
#     530     return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/pymongo/auth.py:298, in _authenticate_scram(credentials, conn, mechanism)
#     289 server_sig = standard_b64encode(_hmac(server_key, auth_msg, digestmod).digest())
#     291 cmd = SON(
#     292     [
#     293         ("saslContinue", 1),
#    (...)
#     296     ]
#     297 )
# --> 298 res = conn.command(source, cmd)
#     300 parsed = _parse_scram_response(res["payload"])
#     301 if not hmac.compare_digest(parsed[b"v"], server_sig):
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/pymongo/helpers.py:322, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     319 from pymongo.pool import Connection
#     321 try:
# --> 322     return func(*args, **kwargs)
#     323 except OperationFailure as exc:
#     324     if no_reauth:
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/pymongo/pool.py:968, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     966     self._raise_if_not_writable(unacknowledged)
#     967 try:
# --> 968     return command(
#     969         self,
#     970         dbname,
#     971         spec,
#     972         self.is_mongos,
#     973         read_preference,
#     974         codec_options,
#     975         session,
#     976         client,
#     977         check,
#     978         allowable_errors,
#     979         self.address,
#     980         listeners,
#     981         self.max_bson_size,
#     982         read_concern,
#     983         parse_write_concern_error=parse_write_concern_error,
#     984         collation=collation,
#     985         compression_ctx=self.compression_context,
#     986         use_op_msg=self.op_msg_enabled,
#     987         unacknowledged=unacknowledged,
#     988         user_fields=user_fields,
#     989         exhaust_allowed=exhaust_allowed,
#     990         write_concern=write_concern,
#     991     )
#     992 except (OperationFailure, NotPrimaryError):
#     993     raise
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/pymongo/network.py:192, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     190             client._process_response(response_doc, session)
#     191         if check:
# --> 192             helpers._check_command_response(
#     193                 response_doc,
#     194                 conn.max_wire_version,
#     195                 allowable_errors,
#     196                 parse_write_concern_error=parse_write_concern_error,
#     197             )
#     198 except Exception as exc:
#     199     if publish:
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/pymongo/helpers.py:230, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     227 elif code == 43:
#     228     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 230 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: Authentication failed., full error: {'ok': 0.0, 'errmsg': 'Authentication failed.', 'code': 18, 'codeName': 'AuthenticationFailed'}
